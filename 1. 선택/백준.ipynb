# %% [markdown]
# # 문제 18108
# 1998년생인 내가 태국에서는 2541년생?!

# %%
y = int(input())
print(y-543)
# Out:
# 2541
# 1998

# %% [markdown]
# # 문제 10807

# %%
N = int(input())
t = input().split()
v = input()

total = 0

for i in range(N):
    if t[i] == v:
        total +=1
    
print(total)
# Out:
# 11
# 1 4 1 2 4 2 4 2 3 4 4
# 2
# 11

# %% [markdown]
# # 문제 15596

# %%
def solve(a):
    ans = 0
    for i in range(len(a)):
        ans += a[i]
    return ans
