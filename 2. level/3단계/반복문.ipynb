# %% [markdown]
# # 1

# %% [markdown]
# # 2

# %% [markdown]
# # 3

# %% [markdown]
# # 4

# %% [markdown]
# # 5

# %% [markdown]
# # 6

# %% [markdown]
# # 7

# %% [markdown]
# # 8

# %% [markdown]
# # 9

# %% [markdown]
# # 10

# %% [markdown]
# # 11

# %% [markdown]
# # 12
