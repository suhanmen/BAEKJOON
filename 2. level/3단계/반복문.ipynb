# %% [markdown]
# # 1

# %%
N = int(input())

for j in range(1,10):
    print('{} * {} = {}'.format(N,j,N*j))
# Out:
# 2
# 2 * 1 = 2
# 2 * 2 = 4
# 2 * 3 = 6
# 2 * 4 = 8
# 2 * 5 = 10
# 2 * 6 = 12
# 2 * 7 = 14
# 2 * 8 = 16
# 2 * 9 = 18

# %% [markdown]
# # 2

# %%
T = int(input())
total = []

for _ in range(T):
    total.append(list(map(int, input().split())))
    
for i in range(T):
    print(sum(total[i]))
# Out:
# 5
# 1 1
# 2 3
# 3 4
# 9 8
# 5 2
# 2
# 5
# 7
# 17
# 7

# %% [markdown]
# # 3

# %%
n = int(input())
total = 0
for i in range(1, n+1):
    total += i
    
print(total)
# Out:
# 3
# 6

# %% [markdown]
# # 4

# %%
X = int(input())
N = int(input())
t = []
total = 0

for _ in range(N):
    t.append(list(map(int, input().split())))
for i in range(N):
    total += t[i][0]*t[i][1]

print('Yes') if X == total else print('No')
# Out:
# 260000
# 4
# 20000 5
# 30000 2
# 10000 6
# 5000 8
# Yes

# %% [markdown]
# # 5

# %%
N = int(input())

print('long '*(N//4)+'int')
# Out:
# 4
# long int

# %% [markdown]
# # 6
# https://velog.io/@yeseolee/Python-%ED%8C%8C%EC%9D%B4%EC%8D%AC-%EC%9E%85%EB%A0%A5-%EC%A0%95%EB%A6%ACsys.stdin.readline

# %%
#import sys
# T = int(sys.stdin.readline().rstrip())
#map(int, sys.stdin.readline().split())

T = int(input())
total = []

for _ in range(T):
    total.append(sum(map(int, input().split())))
    
for i in range(T):
    print(total[i])
# Out:
# 2
# 1 3
# 4 5
# 4
# 9

# %% [markdown]
# # 7

# %%
#import sys
# T = int(sys.stdin.readline().rstrip())
#map(int, sys.stdin.readline().split())

T = int(input())
total = []

for _ in range(T):
    total.append(sum(map(int,input().split())))
    
for i in range(T):
    print('Case #{}: {}'.format(i+1,total[i]))
# Out:
# 5
# 1 1
# 2 3
# 3 4
# 9 8
# 5 2
# Case #1: 2
# Case #2: 5
# Case #3: 7
# Case #4: 17
# Case #5: 7

# %% [markdown]
# # 8

# %%
#import sys
#T = int(sys.stdin.readline().rstrip())
#map(int,sys.stdin.readline().split())

T = int(input())
total = []

for _ in range(T):
    total.append(list(map(int,input().split())))

for i in range(T):
    print('Case #{}: {} + {} = {}'.format(i+1, total[i][0], total[i][1], sum(total[i])))
# Out:
# 2
# 3 5
# 2 5
# Case #1: 3 + 5 =  8
# Case #2: 2 + 5 =  7

# %% [markdown]
# # 9

# %%
t = int(input())

for i in range(1,t+1):
    print('*'*i)
# Out:
# 5
# *
# **
# ***
# ****
# *****

# %% [markdown]
# # 10

# %%
t = int(input())

for i in range(1,t+1):
    print(' '*(t-i) + '*'*i)
# Out:
# 5
#     *
#    **
#   ***
#  ****
# *****

# %% [markdown]
# # 11

# %%
total = []
while [0,0] not in total:
    total.append(list(map(int, input().split())))

for i in range(len(total)-1):
    print(sum(total[i]))
# Out:
# 1 1
# 2 3
# 4 5
# 4 5
# 0 0
# 2
# 5
# 9
# 9

# %% [markdown]
# # 12 try, except 기억하기
# https://taltal.tistory.com/m/111

# %%
while True:
    try:
        A, B= map(int,input().split())
        print(A+B)
    except:
        break
# Out:
# 2 5
# 7
# 4 5
# 9
